# %%
# git clone https://github.com/valmirf/redes_neurais_bcc.git

# %%
# Neste código vou utilizar o pandas, framework amplamente utilizado pra lidar com dados
import pandas as pd
from sklearn.model_selection import train_test_split


#carrega a base de dados e retorna conjuntos de treinamento e teste
def load_data():
    url = 'redes_neurais_bcc/Perceptron/diabetes.csv'
    df = pd.read_csv(url)
    #remove a ultima coluna (dados)
    data = df[df.columns[:-1]]
    #normaliza os dados
    normalized_data = (data - data.min()) / (data.max() - data.min())
    #retorna a última coluna (rótulos)
    labels = df[df.columns[-1]]
    #separa em conjunto de treinamento e teste com seus respectivos rótulos
    X_train, X_test, y_train, y_test = train_test_split(normalized_data, labels, test_size=0.2, random_state=0)

    return X_train, X_test, y_train, y_test

#chama função que carrega base de dados
training_inputs, test_inputs, training_labels, test_labels = load_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_229/239924440.py in <cell line: 0>()
#      20
#      21 #chama função que carrega base de dados
# ---> 22 training_inputs, test_inputs, training_labels, test_labels = load_data()
#
# /tmp/ipykernel_229/239924440.py in load_data()
#       7 def load_data():
#       8     url = 'redes_neurais_bcc/Perceptron/diabetes.csv'
# ----> 9     df = pd.read_csv(url)
#      10     #remove a ultima coluna (dados)
#      11     data = df[df.columns[:-1]]
#
# ...

# %%
training_inputs.shape
# Out:
# (613, 8)

# %% [markdown]
# ## Atividade

# %% [markdown]
# Implemente um Perceptron (estruturado como uma classe) , e utilize a base "diabetes" para treinar e validar seu modelo. O código acima faz a leitura da base e a divide em treino e teste. Realize o treinamento com o conjunto de treino, e obtenha a acurácia no conjunto de teste, realizando os seguintes experimentos.
#
# 1. Teste 2 variações de taxas de aprendizado: (0.1 e 0.01)
# 2. Troque o Perceptron pelo Adaline, mudando a função de atualização dos Pesos. Verifique como se comporta (se converge mais rápido e se melhora o resultado).
# 3. Mostre os resultados obtidos

# %%
import numpy as np

class Perceptron(object):

    def __init__(self, no_of_inputs,  nIterations=100, learning_rate=0.01):


    def predict(self, inputs):


    def train(self, training_inputs, labels):
